# %% [markdown]
# <a href="https://colab.research.google.com/github/yesung05/2024-intro-DA-code/blob/main/w07_matplotlib_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CHAPTER 05 Matplotlib를 활용한 데이터 시각화 기초
# # SECTION 01 데이터 시각화 기초

# %% [markdown]
# ## 설치 확인과 한글처리 준비

# %%
import numpy as np
import matplotlib as mpl

print(np.__version__)
print(mpl.__version__)
# Out:
# 1.26.4
# 3.8.0

# %%
# %config InlineBackend.figure_format = 'retina' #그림 선명하게 하는 명령어

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib #한글처리
# plt.rc('font', family='Malgun Gothic') #폰트 설정
# plt.rc('axes', unicode_minus=False) #- 설정
#코랩에서는 koreanize matplotlib

# %% [markdown]
# ### plt.rcParams[]으로도 가능

# %%
# plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 간단한 직선 그래프 그리기

# %%
# !pip install koreanize_matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 50.1 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
plt.plot([10,5,25,30,20])
plt.show()

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
#plt.rcParams['font.family'] = 'Malgun Gothic'
#plt.rcParams['axes.unicode_minus'] = False
#코랩이라 필요 X

plt.plot([1,3,5,7,9],[8,6,17,22,3])
plt.title('직선 그래프 그리기')
plt.show()

# %% [markdown]
# ## 그래프의 여러 속성

# %%
import matplotlib.pyplot as plt

#데이터 생성
x = [1,2,3,4,5]
y = [2,3,5,7,11]

plt.plot(x,y,marker='o', linestyle='-', color='b', label='소수(Prime Numbers)')

plt.xlabel('X-축(axis)')
plt.ylabel('Y-축(axis)')
plt.title('소수 그리기(Prime Numbers Plot)')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt #이거 계속 적을 필요는 없음..

plt.plot([1,2,3,4],[10,20,30,40],'--r', marker='d', linewidth=3, label = 'thick line')

plt.plot([1,2,3,4],[40,30,20,10],'b', ls=':', marker='^', lw=0.5, label = 'thin line')

plt.title('속성 marker linewidth linestyle')
plt.xlabel('X 축(axis)')
plt.ylabel('Y 축(axis)')

plt.legend()
plt.show()

# %% [markdown]
# ## 산점도

# %%
import numpy as np
import matplotlib.pyplot as plt

#Fixing random state for reproducibility
np.random.seed(2025) #컴퓨터에 완벽한 랜덤은 없다
# https://matplotlib.org/3.1.1/gallery/shapes_and_collections/scatter.html 여기서 가져온 코드구만
N = 80
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.7)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(-100,100,1000)
y = np.random.randint(-100,100,1000)

mask1 = abs(x) > 50 #x에서 나온 값을 절대값(양수)으로 변환 그중 50이 넘는 수
mask2 = abs(y) > 50
x = x[mask1 + mask2]
y = y[mask1 + mask2]

plt.scatter(x,y,c=x,cmap = 'jet',alpha = 0.4)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(-100,100,1000)
y = np.random.randint(-100,100,1000)

mask1 = abs(x) > 50 #x에서 나온 값을 절대값(양수)으로 변환 그중 50이 넘는 수
mask2 = abs(y) > 50
x = x[mask1 * mask2]
y = y[mask1 * mask2]

plt.scatter(x,y,c=x,cmap = 'jet',alpha = 0.4)
plt.colorbar()
plt.show()
