# %% [markdown]
# <a href="https://colab.research.google.com/github/yesung05/2024-intro-DA-code/blob/main/10_minutes_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/10min.html

# %% [markdown]
# # 10 Minutes to pandas
#
# This is a short introduction to pandas, geared mainly for new users. You can see more complex recipes in the [Cookbook](http://pandas.pydata.org/pandas-docs/stable/cookbook.html#cookbook)

# %% [markdown]
# Customarily, we import as follows:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## Object Creation
#
# See the [Data Structure Intro section](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dsintro)

# %% [markdown]
# Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a DataFrame by passing a numpy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.978256  1.216713  0.832040 -1.113555
# 2013-01-02  1.507918 -1.079444 -0.646008  1.332537
# 2013-01-03 -0.134598  0.361295 -0.573702  0.037295
# 2013-01-04 -1.425639 -0.283110 -1.522729  1.704675
# 2013-01-05 -0.068913  1.217380 -1.732410  0.100413
# 2013-01-06 -0.102809  1.114811 -0.490176 -1.598669

# %% [markdown]
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({'A':1.,
                   'B':pd.Timestamp('20130102'),
                   'C':pd.Series(1,index=list(range(4)),dtype='float32'),
                   'D':np.array([3]*4,dtype='int32'),
                   'E':pd.Categorical(["test","train","test","train"]),
                   'F':'foo'})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# Having specific [dtypes](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes)

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# If you’re using IPython, tab completion for column names (as well as public attributes) is automatically enabled. Here’s a subset of the attributes that will be completed:

# %%
# df2.<TAB>

# %% [markdown]
# As you can see, the columns A, B, C, and D are automatically tab completed. E is there as well; the rest of the attributes have been truncated for brevity.

# %% [markdown]
# ## Viewing Data
#
# See the [Basics section](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics)

# %% [markdown]
# See the top & bottom rows of the frame

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.978256  1.216713  0.832040 -1.113555
# 2013-01-02  1.507918 -1.079444 -0.646008  1.332537
# 2013-01-03 -0.134598  0.361295 -0.573702  0.037295
# 2013-01-04 -1.425639 -0.283110 -1.522729  1.704675
# 2013-01-05 -0.068913  1.217380 -1.732410  0.100413

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -1.425639 -0.283110 -1.522729  1.704675
# 2013-01-05 -0.068913  1.217380 -1.732410  0.100413
# 2013-01-06 -0.102809  1.114811 -0.490176 -1.598669

# %% [markdown]
# Display the index, columns, and the underlying numpy data

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.97825604,  1.21671331,  0.83204036, -1.11355497],
#        [ 1.50791828, -1.07944389, -0.64600842,  1.3325369 ],
#        [-0.134598  ,  0.36129533, -0.57370168,  0.03729521],
#        [-1.42563929, -0.28311038, -1.52272927,  1.7046746 ],
#        [-0.06891285,  1.21737973, -1.73241042,  0.10041328],
#        [-0.10280882,  1.11481144, -0.49017564, -1.59866864]])

# %% [markdown]
# Describe shows a quick statistic summary of your data

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.125703  0.424608 -0.688831  0.077116
# std    1.019988  0.948614  0.911268  1.300239
# min   -1.425639 -1.079444 -1.732410 -1.598669
# 25%   -0.126651 -0.122009 -1.303549 -0.825842
# 50%   -0.085861  0.738053 -0.609855  0.068854
# 75%    0.716464  1.191238 -0.511057  1.024506
# max    1.507918  1.217380  0.832040  1.704675

# %% [markdown]
# Transposing your data

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.978256    1.507918   -0.134598   -1.425639   -0.068913   -0.102809
# B    1.216713   -1.079444    0.361295   -0.283110    1.217380    1.114811
# C    0.832040   -0.646008   -0.573702   -1.522729   -1.732410   -0.490176
# D   -1.113555    1.332537    0.037295    1.704675    0.100413   -1.598669

# %% [markdown]
# Sorting by an axis

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.113555  0.832040  1.216713  0.978256
# 2013-01-02  1.332537 -0.646008 -1.079444  1.507918
# 2013-01-03  0.037295 -0.573702  0.361295 -0.134598
# 2013-01-04  1.704675 -1.522729 -0.283110 -1.425639
# 2013-01-05  0.100413 -1.732410  1.217380 -0.068913
# 2013-01-06 -1.598669 -0.490176  1.114811 -0.102809

# %% [markdown]
# Sorting by value

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-02  1.507918 -1.079444 -0.646008  1.332537
# 2013-01-04 -1.425639 -0.283110 -1.522729  1.704675
# 2013-01-03 -0.134598  0.361295 -0.573702  0.037295
# 2013-01-06 -0.102809  1.114811 -0.490176 -1.598669
# 2013-01-01  0.978256  1.216713  0.832040 -1.113555
# 2013-01-05 -0.068913  1.217380 -1.732410  0.100413

# %% [markdown]
# ## Selection

# %% [markdown]
# **Note:** While standard Python / Numpy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, .at, .iat, .loc, .iloc and .ix.

# %% [markdown]
# See the indexing documentation [Indexing and Selecting Data](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing) and [MultiIndex / Advanced Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced)

# %% [markdown]
# ### Getting

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to df.A

# %%
df['A']
# Out:
# 2013-01-01    0.978256
# 2013-01-02    1.507918
# 2013-01-03   -0.134598
# 2013-01-04   -1.425639
# 2013-01-05   -0.068913
# 2013-01-06   -0.102809
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# Selecting via [], which slices the rows.

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.978256  1.216713  0.832040 -1.113555
# 2013-01-02  1.507918 -1.079444 -0.646008  1.332537
# 2013-01-03 -0.134598  0.361295 -0.573702  0.037295

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02  1.507918 -1.079444 -0.646008  1.332537
# 2013-01-03 -0.134598  0.361295 -0.573702  0.037295
# 2013-01-04 -1.425639 -0.283110 -1.522729  1.704675

# %% [markdown]
# ### Selection by Label
#
# See more in [Selection by Label](Selection by Label)

# %% [markdown]
# For getting a cross section using a label

# %%
df.loc[dates[0]]
# Out:
# A    0.978256
# B    1.216713
# C    0.832040
# D   -1.113555
# Name: 2013-01-01 00:00:00, dtype: float64

# %% [markdown]
# Selection by Label

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01  0.978256  1.216713
# 2013-01-02  1.507918 -1.079444
# 2013-01-03 -0.134598  0.361295
# 2013-01-04 -1.425639 -0.283110
# 2013-01-05 -0.068913  1.217380
# 2013-01-06 -0.102809  1.114811

# %% [markdown]
# Showing label slicing, both endpoints are included

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02  1.507918 -1.079444
# 2013-01-03 -0.134598  0.361295
# 2013-01-04 -1.425639 -0.283110

# %% [markdown]
# Reduction in the dimensions of the returned object

# %%
df.loc['20130102',['A','B']]
# Out:
# A    1.507918
# B   -1.079444
# Name: 2013-01-02 00:00:00, dtype: float64

# %% [markdown]
# For getting a scalar value

# %%
df.loc[dates[0],'A']
# Out:
# 0.9782560439901615

# %% [markdown]
# ### Selection by Position
#
# See more in [Selection by Position](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-integer)

# %% [markdown]
# Select via the position of the passed integers

# %%
df.iloc[3]
# Out:
# A   -1.425639
# B   -0.283110
# C   -1.522729
# D    1.704675
# Name: 2013-01-04 00:00:00, dtype: float64

# %% [markdown]
# By integer slices, acting similar to numpy/python

# %%
df.iloc[3:5,0:2]
# Out:
#                    A        B
# 2013-01-04 -1.425639 -0.28311
# 2013-01-05 -0.068913  1.21738

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02  1.507918 -0.646008
# 2013-01-03 -0.134598 -0.573702
# 2013-01-05 -0.068913 -1.732410

# %% [markdown]
# For slicing rows explicitly

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02  1.507918 -1.079444 -0.646008  1.332537
# 2013-01-03 -0.134598  0.361295 -0.573702  0.037295

# %% [markdown]
# For slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01  1.216713  0.832040
# 2013-01-02 -1.079444 -0.646008
# 2013-01-03  0.361295 -0.573702
# 2013-01-04 -0.283110 -1.522729
# 2013-01-05  1.217380 -1.732410
# 2013-01-06  1.114811 -0.490176

# %% [markdown]
# For getting a value explicitly

# %%
df.iloc[1,1]
# Out:
# -1.0794438904892816

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.iat[1,1]
# Out:
# -1.0794438904892816

# %% [markdown]
# ## Boolean Indexing

# %% [markdown]
# Using a single column’s values to select data.

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.978256  1.216713  0.832040 -1.113555
# 2013-01-02  1.507918 -1.079444 -0.646008  1.332537

# %% [markdown]
# A where operation for getting.

# %%
df[df > 0]
# Out:
#                    A         B        C         D
# 2013-01-01  0.978256  1.216713  0.83204       NaN
# 2013-01-02  1.507918       NaN      NaN  1.332537
# 2013-01-03       NaN  0.361295      NaN  0.037295
# 2013-01-04       NaN       NaN      NaN  1.704675
# 2013-01-05       NaN  1.217380      NaN  0.100413
# 2013-01-06       NaN  1.114811      NaN       NaN

# %% [markdown]
# Using the isin() method for filtering:

# %%
df2 = df.copy()

# %%
df2['E'] = ['one','one', 'two','three','four','three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.978256  1.216713  0.832040 -1.113555    one
# 2013-01-02  1.507918 -1.079444 -0.646008  1.332537    one
# 2013-01-03 -0.134598  0.361295 -0.573702  0.037295    two
# 2013-01-04 -1.425639 -0.283110 -1.522729  1.704675  three
# 2013-01-05 -0.068913  1.217380 -1.732410  0.100413   four
# 2013-01-06 -0.102809  1.114811 -0.490176 -1.598669  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.134598  0.361295 -0.573702  0.037295   two
# 2013-01-05 -0.068913  1.217380 -1.732410  0.100413  four

# %% [markdown]
# ## Setting

# %% [markdown]
# Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102',periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %% [markdown]
# Setting values by label

# %%
df.at[dates[0],'A'] = 0

# %% [markdown]
# Settomg values by position

# %%
df.iat[0,1] = 0

# %% [markdown]
# Setting by assigning with a numpy array

# %%
df.loc[:,'D'] = np.array([5] * len(df))

# %% [markdown]
# The result of the prior setting operations

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  0.832040  5.0  NaN
# 2013-01-02  1.507918 -1.079444 -0.646008  5.0  1.0
# 2013-01-03 -0.134598  0.361295 -0.573702  5.0  2.0
# 2013-01-04 -1.425639 -0.283110 -1.522729  5.0  3.0
# 2013-01-05 -0.068913  1.217380 -1.732410  5.0  4.0
# 2013-01-06 -0.102809  1.114811 -0.490176  5.0  5.0

# %% [markdown]
# A where operation with setting.

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.832040 -5.0  NaN
# 2013-01-02 -1.507918 -1.079444 -0.646008 -5.0 -1.0
# 2013-01-03 -0.134598 -0.361295 -0.573702 -5.0 -2.0
# 2013-01-04 -1.425639 -0.283110 -1.522729 -5.0 -3.0
# 2013-01-05 -0.068913 -1.217380 -1.732410 -5.0 -4.0
# 2013-01-06 -0.102809 -1.114811 -0.490176 -5.0 -5.0

# %% [markdown]
# ## Missing Data
#
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations. See the Missing Data section

# %% [markdown]
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])

# %%
df1.loc[dates[0]:dates[1],'E'] = 1

# %%
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  0.832040  5.0  NaN  1.0
# 2013-01-02  1.507918 -1.079444 -0.646008  5.0  1.0  1.0
# 2013-01-03 -0.134598  0.361295 -0.573702  5.0  2.0  NaN
# 2013-01-04 -1.425639 -0.283110 -1.522729  5.0  3.0  NaN

# %% [markdown]
# To drop any rows that have missing data.

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C    D    F    E
# 2013-01-02  1.507918 -1.079444 -0.646008  5.0  1.0  1.0

# %% [markdown]
# Filling missing data

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  0.832040  5.0  5.0  1.0
# 2013-01-02  1.507918 -1.079444 -0.646008  5.0  1.0  1.0
# 2013-01-03 -0.134598  0.361295 -0.573702  5.0  2.0  5.0
# 2013-01-04 -1.425639 -0.283110 -1.522729  5.0  3.0  5.0

# %% [markdown]
# To get the boolean mask where values are nan

# %%
pd.isnull(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Operations
#
# See the [Basic section on Binary Ops](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-binop)

# %% [markdown]
# ### Stats
#
# Operations in general exclude missing data.

# %% [markdown]
# Performing a descriptive statistic

# %%
df.mean()
# Out:
# A   -0.037340
# B    0.221822
# C   -0.688831
# D    5.000000
# F    3.000000
# dtype: float64

# %% [markdown]
# Same operation on the other axis

# %%
df.mean(1)
# Out:
# 2013-01-01    1.458010
# 2013-01-02    1.156493
# 2013-01-03    1.330599
# 2013-01-04    0.953704
# 2013-01-05    1.683211
# 2013-01-06    2.104365
# Freq: D, dtype: float64

# %% [markdown]
# Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension.

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.134598 -0.638705 -1.573702  4.0  1.0
# 2013-01-04 -4.425639 -3.283110 -4.522729  2.0  0.0
# 2013-01-05 -5.068913 -3.782620 -6.732410  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ### Apply

# %% [markdown]
# Applying functions to the data

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C     D     F
# 2013-01-01  0.000000  0.000000  0.832040   5.0   NaN
# 2013-01-02  1.507918 -1.079444  0.186032  10.0   1.0
# 2013-01-03  1.373320 -0.718149 -0.387670  15.0   3.0
# 2013-01-04 -0.052319 -1.001259 -1.910399  20.0   6.0
# 2013-01-05 -0.121232  0.216121 -3.642809  25.0  10.0
# 2013-01-06 -0.224041  1.330932 -4.132985  30.0  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.933558
# B    2.296824
# C    2.564451
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# ### Histogramming
#
# See more at [Histogramming and Discretization](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-discretization)

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    4
# 1    1
# 2    4
# 3    2
# 4    6
# 5    3
# 6    6
# 7    1
# 8    0
# 9    6
# dtype: int64

# %%
s.value_counts()
# Out:
# 6    3
# 4    2
# 1    2
# 2    1
# 3    1
# 0    1
# Name: count, dtype: int64

# %% [markdown]
# ### String Methods
#
# Series is equipped with a set of string processing methods in the str attribute that make it easy to operate on each element of the array, as in the code snippet below. Note that pattern-matching in str generally uses [regular expressions](https://docs.python.org/2/library/re.html) by default (and in some cases always uses them). See more at [Vectorized String Methods](http://pandas.pydata.org/pandas-docs/stable/text.html#text-string-methods).

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Merge

# %% [markdown]
# ### Concat
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# See the [Merging section](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging)

# %% [markdown]
# Concatenating pandas objects together with concat():

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  2.193441 -0.413773  0.441998 -1.143447
# 1  1.192791 -0.381611  1.004629 -0.540151
# 2 -0.392051  0.634803 -0.263005 -1.299749
# 3 -0.940822  0.417255  0.833246  1.378065
# 4  1.723003  0.436969  1.533839  0.301773
# 5  0.353347 -0.378618  0.364594 -2.095538
# 6  0.700417  0.494789 -0.919860  0.529785
# 7  1.479026  0.673433 -0.501131 -1.158223
# 8  0.114540  0.224813 -0.634280 -0.881326
# 9  0.116225  0.494350  1.385954  0.293644

# %%
# break it into pieces
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  2.193441 -0.413773  0.441998 -1.143447
# 1  1.192791 -0.381611  1.004629 -0.540151
# 2 -0.392051  0.634803 -0.263005 -1.299749
# 3 -0.940822  0.417255  0.833246  1.378065
# 4  1.723003  0.436969  1.533839  0.301773
# 5  0.353347 -0.378618  0.364594 -2.095538
# 6  0.700417  0.494789 -0.919860  0.529785
# 7  1.479026  0.673433 -0.501131 -1.158223
# 8  0.114540  0.224813 -0.634280 -0.881326
# 9  0.116225  0.494350  1.385954  0.293644

# %% [markdown]
# ### Join
#
# SQL style merges. See the [Database style joining](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging-join)

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# ### Append
#
# Append rows to a dataframe. See the [Appending](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging-concatenation)

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])

# %%
df
# Out:
#           A         B         C         D
# 0 -0.040134 -0.291517  0.763602  0.160887
# 1 -1.348249  0.038650 -0.205543  0.835179
# 2  1.175923 -1.002557 -0.476293  0.467151
# 3 -1.979732 -1.203599 -0.222782  1.636155
# 4 -0.139856 -0.754949  1.653058 -1.377658
# 5  1.177138  0.893207 -0.003463 -0.552066
# 6 -0.804322  1.537988  0.963528  0.064834
# 7  2.595001 -0.359917  0.058623 -1.431587

# %%
s = df.iloc[3]

# %%
df.append(s, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-06ff88a5cf39> in <cell line: 1>()
# ----> 1 df.append(s, ignore_index=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps
#
# * **Splitting** the data into groups based on some criteria
# * **Applying** a function to each group independently
# * **Combining** the results into a data structure
#
# See the [Grouping section](http://pandas.pydata.org/pandas-docs/stable/groupby.html#groupby)

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                                    'B' : ['one', 'one', 'two', 'three','two', 'two', 'one', 'three'],
                                    'C' : np.random.randn(8),
                                     'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -1.583984 -0.445668
# 1  bar    one -0.375595 -1.299666
# 2  foo    two  2.141154  1.190335
# 3  bar  three  2.143731 -1.249859
# 4  foo    two  0.142923 -0.302830
# 5  bar    two -0.176749 -0.972997
# 6  foo    one  0.488099 -0.541359
# 7  foo  three  1.631500 -0.216253

# %% [markdown]
# Grouping and then applying a function sum to the resulting groups.

# %%
df.groupby('A').sum()
# Out:
#                      B         C         D
# A
# bar        onethreetwo  1.591386 -3.522522
# foo  onetwotwoonethree  2.819692 -0.315775

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.375595 -1.299666
#     three  2.143731 -1.249859
#     two   -0.176749 -0.972997
# foo one   -1.095885 -0.987027
#     three  1.631500 -0.216253
#     two    2.284077  0.887505

# %% [markdown]
# ## Reshaping
#
# See the sections on [Hierarchical Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced-hierarchical) and [Reshaping](http://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-stacking).

# %% [markdown]
# ### Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
                                ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]))

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -1.773134  0.169677
#       two    -1.682857 -1.138430
# baz   one    -2.534573  0.207273
#       two    -1.499854  0.057646

# %% [markdown]
# The stack() method “compresses” a level in the DataFrame’s columns.

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A   -1.773134
#                B    0.169677
#        two     A   -1.682857
#                B   -1.138430
# baz    one     A   -2.534573
#                B    0.207273
#        two     A   -1.499854
#                B    0.057646
# dtype: float64

# %% [markdown]
# With a “stacked” DataFrame or Series (having a MultiIndex as the index), the inverse operation of stack() is unstack(), which by default unstacks the **last level**:

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -1.773134  0.169677
#       two    -1.682857 -1.138430
# baz   one    -2.534573  0.207273
#       two    -1.499854  0.057646

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -1.773134 -1.682857
#       B  0.169677 -1.138430
# baz   A -2.534573 -1.499854
#       B  0.207273  0.057646

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -1.773134 -2.534573
#        B  0.169677  0.207273
# two    A -1.682857 -1.499854
#        B -1.138430  0.057646

# %% [markdown]
# ### Pivot Tables
#
# See the section on [Pivot Tables](http://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-pivot).

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                                    'B' : ['A', 'B', 'C'] * 4,
                                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                                    'D' : np.random.randn(12),
                                    'E' : np.random.randn(12)})

# %%
df

# %% [markdown]
# We can produce pivot tables from this data very easily:

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])

# %% [markdown]
# ## Time Series
#
# pandas has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (e.g., converting secondly data into 5-minutely data). This is extremely common in, but not limited to, financial applications. See the [Time Series section](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#timeseries)

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample('5Min').sum()

# %% [markdown]
# Time zone representation

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc

# %% [markdown]
# Convert to another time zone

# %%
ts_utc.tz_convert('US/Eastern')

# %% [markdown]
# Converting between time span representations

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts

# %%
ps = ts.to_period()

# %%
ps

# %%
ps.to_timestamp()

# %% [markdown]
# Converting between period and timestamp enables some convenient arithmetic functions to be used. In the following example, we convert a quarterly frequency with year ending in November to 9am of the end of the month following the quarter end:

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

# %%
ts.head()

# %% [markdown]
# ## Categoricals

# %% [markdown]
# Since version 0.15, pandas can include categorical data in a DataFrame. For full docs, see the [categorical introduction](http://pandas.pydata.org/pandas-docs/stable/categorical.html#categorical) and the [API documentation](http://pandas.pydata.org/pandas-docs/stable/api.html#api-categorical).

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})

# %% [markdown]
# Convert the raw grades to a categorical data type.

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]

# %% [markdown]
# Rename the categories to more meaningful names (assigning to Series.cat.categories is inplace!)

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %% [markdown]
# Reorder the categories and simultaneously add the missing categories (methods under Series .cat return a new Series per default).

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])

# %%
df["grade"]

# %% [markdown]
# Sorting is per order in the categories, not lexical order.

# %%
df.sort_values(by="grade")

# %% [markdown]
# Grouping by a categorical column shows also empty categories.

# %%
df.groupby("grade").size()

# %% [markdown]
# ## Plotting
# [Plotting](http://pandas.pydata.org/pandas-docs/stable/visualization.html#visualization) docs.

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %% [markdown]
# On DataFrame, plot() is a convenience to plot all of the columns with labels:

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()

# %%
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# ## Getting Data In/Out

# %% [markdown]
# ### CSV
# [Writing to a csv file](http://pandas.pydata.org/pandas-docs/stable/io.html#io-store-in-csv)

# %%
df.to_csv('foo.csv')

# %% [markdown]
# [Reading from a csv file](http://pandas.pydata.org/pandas-docs/stable/io.html#io-read-csv-table)

# %%
pd.read_csv('foo.csv')

# %% [markdown]
# ### HDF5
# Reading and writing to [HDFStores](http://pandas.pydata.org/pandas-docs/stable/io.html#io-hdf5)
#
# Writing to a HDF5 Store

# %%
df.to_hdf('foo.h5','df')

# %% [markdown]
# Reading from a HDF5 Store

# %%
pd.read_hdf('foo.h5','df')

# %% [markdown]
# ### Excel
#
# Reading and writing to [MS Excel](http://pandas.pydata.org/pandas-docs/stable/io.html#io-excel)
#
# Writing to an excel file

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %% [markdown]
# Reading from an excel file

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])

# %% [markdown]
# ### Gotchas
# If you are trying an operation and you see an exception like:

# %%
if pd.Series([False, True, False]):
    print("I was true")

# %% [markdown]
# See [Comparisons](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-compare) for an explanation and what to do.
#
# See [Gotchas](http://pandas.pydata.org/pandas-docs/stable/gotchas.html#gotchas) as well.
